# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\hp\Downloads\CardioGoodFitness.csv")

# %%
#Q1 Python program to display the sum of n numbers using the list


num1 = input('Enter first number: ')
num2 = input('Enter second number: ')
num3 = input('Enter third number')
sum = int(num1) + int(num2) + int(num3)
print(sum)
# Out:
# Enter first number: 2
# Enter second number: 2
# Enter third number2
# 6

# %%
#Q2   Python function which counts vowels and consonant in a word


str=input("enter a string: ");
vowels=0
consonants=0
str.upper()
for i in str:
    if(i=='a'or i=='e'or i=='i'or i=='o'or i=='u'):
           vowels=vowels+1;
    else:
        consonants=consonants+1;
print("The number of vowels:",vowels);
print("\nThe number of consonant:",consonants);
# Out:
# enter a string: vidya dwaraka sahani
# The number of vowels: 8
#
# The number of consonant: 12

# %%
print('*Welcome to State bank of India:*\n')

Balance = 25000

name = int(input("Enter your 4 digit pin Number:"))

choice = int(input("Please choose transaction: \n1-Withdrow \n2-Balance Enquiry \n3-Fast-Cash \nPlease choose transaction:"))

if choice==1:
    a = int(input("Enter withdrowl amount:"))
    Balance = Balance-a
    print("Please take your amount:", a, "\nBalance:",Balance)
elif choice==2:
    print("Your Balance is:", Balance)
elif choice==3:
    pass
else:
    print("Wrong choice")
# Out:
# *Welcome to State bank of India:*
#
# Enter your 4 digit pin Number:1234
# Please choose transaction:
# 1-Withdrow
# 2-Balance Enquiry
# 3-Fast-Cash
# Please choose transaction:2
# Your Balance is: 25000

# %%
#Q5 {The objective of this project is to explore a dataset containing customer information for 
#treadmill products for a retail store called Cardio Good Fitness.


#•Product - The model no. of the treadmill
#•Age - Age of the customer in no of years
#•Gender - Gender of the customer
#•Education - Education of the customer in no. of years
#•Marital Status - Marital status of the customer
#•Usage - Avg. # times the customer wants to use the treadmill every week
#•Fitness - Self rated fitness score of the customer (5 - very fit, 1 - very unfit)
#•Income - Income of the customer
#•Miles- Miles that a customer expects to run

#a.Perform descriptive statistics
#b.Which gender has better fitness levels?
#c.Which is the most popular product among all?
#d.Who is more fit? Married or singles
#e.Which is the most favourite product of the customers below the age of 40?


df=pd.read_csv(r"C:\Users\hp\Downloads\CardioGoodFitness.csv")

# %%
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
df.tail()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   TM798   40   Male         21        Single      6        5   83416
# 176   TM798   42   Male         18        Single      5        4   89641
# 177   TM798   45   Male         16        Single      5        5   90886
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
df.shape
# Out:
# (180, 9)

# %%
df.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %%
df.Gender.value_counts()
# Out:
# Male      104
# Female     76
# Name: Gender, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,9))
sns.pairplot(data=df,corner=True)

# %%
#a. perform descriptive stat
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
#c.Which is the most popular product among all?
df.Product.value_counts()
# Out:
# TM195    80
# TM498    60
# TM798    40
# Name: Product, dtype: int64

# %%
### Python Program to Make a Simple Calculator


#This function adds two numbers
def addition(a, b):
    return a + b

# This function subtracts two numbers
def subtraction(a, b):
    return a - b

# This function multiplies two numbers
def multiplication(a, b):
    return a * b

# This function divides two numbers
def division(a, b):
    return a / b


print("Choose the Operation.")
print("1.Addition")
print("2.Subtraction")
print("3.Multiplication")
print("4.Division")

while True:
    # take input from the user
    choice = input("Select the Operation which perform (1/2/3/4): ")

    # check if choice is one of the four options
    if choice in ('1', '2', '3', '4'):
        try:
            n1 = float(input("Enter your  first number: "))
            n2 = float(input("Enter your second number: "))
        except ValueError:
            print("Invalid number. Please enter a correct  number.")
            continue

        if choice == '1':
            print(n1, "+", n2, "=", addition(n1, n2))

        elif choice == '2':
            print(n1, "-", n2, "=", subtraction(n1, n2))

        elif choice == '3':
            print(n1, "*", n2, "=", multiplication(n1, n2))

        elif choice == '4':
            print(n1, "/", n2, "=", division(n1, n2))
        
# Check if user wants to perform another calculation operation.
# Break the while loop if answer is "No"
        next_calculation = input(" If you want to continue with next calculation operation? (Yes/No): ")
        if next_calculation == "No":
          break
    else:
        print("Invalid Input")
# Out:
# Choose the Operation.
# 1.Addition
# 2.Subtraction
# 3.Multiplication
# 4.Division
# Select the Operation which perform (1/2/3/4): 1
# Enter your  first number: 2
# Enter your second number: 4
# 2.0 + 4.0 = 6.0
#  If you want to continue with next calculation operation? (Yes/No): No
